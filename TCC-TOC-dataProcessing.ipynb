# %%
import pandas as pd
import seaborn as srn
import statistics as sts
import datetime

# %%
df = pd.read_csv('pns-reduzido-2019.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unidade da Federação  \
# 0           0                    11
# 1           1                    11
# 2           2                    11
# 3           3                    11
# 4           4                    11
#
#    Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?   \
# 0                                                2.0
# ...

# %%
print(df.shape)
# Out:
# (293726, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293726 entries, 0 to 293725
# Data columns (total 21 columns):
#  #   Column                                                                                                                                                                                                                                                             Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                             --------------   -----
#  0   Unnamed: 0                                                                                                                                                                                                                                                         293726 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  Unidade da Federação  \
# count  293726.000000         293726.000000
# mean   146862.500000             28.844716
# std     84791.536921             11.762108
# min         0.000000             11.000000
# 25%     73431.250000             21.000000
# 50%    146862.500000             27.000000
# 75%    220293.750000             35.000000
# max    293725.000000             53.000000
#
#        Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?   \
# count                                        4905.000000
# mean                                            1.938634
# std                                             0.240025
# min                                             1.000000
# 25%                                             2.000000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                                0
# Unidade da Federação                                                                                                                                                                                                                                                      0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?     288821
# ...

# %% [markdown]
# ## Processar colunas

# %%
df = pd.read_csv('pns-reduzido-2019.csv')

# %%
now = datetime.datetime.now()
# Defina os limites de idade desejados
limite_inferior = 1
limite_superior = 120

# Filtrar linhas com idade dentro do intervalo desejado
df = df[(df['Ano de nascimento'] <= (now.year - limite_inferior)) & (df['Ano de nascimento'] >= (now.year - limite_superior))]

# Agora, df contém apenas as linhas com idade dentro do intervalo especificado (7 a 130 anos)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                                0
# Unidade da Federação                                                                                                                                                                                                                                                      0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?     258260
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Unidade da Federação  \
# 0           0                    11
# 1           1                    11
# 2           2                    11
# 6           6                    11
# 7           7                    11
#
#    Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?   \
# 0                                                2.0
# ...

# %%
# Antes de aplicar o dropna
print(df.shape)

# Aplicar o dropna
df.dropna(subset=['Diagnóstico de TOC (Transtorno obsessivo compulsivo) '], inplace=True)

# Depois de aplicar o dropna
print(df.shape)

# Verificar a presença de valores nulos na coluna
print(df['Diagnóstico de TOC (Transtorno obsessivo compulsivo) '].isnull().sum())
# Out:
# (263040, 21)
# (4780, 21)
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                              0
# Unidade da Federação                                                                                                                                                                                                                                                    0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?        0
# ...

# %%
df = df.drop(columns=['Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)'])
df = df.drop(columns=['Qual é o curso que frequenta'])
df = df.drop(columns=['E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente? '])
df = df.drop(columns=['Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)'])
df = df.drop(columns=[' Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas '])

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                           0
# Unidade da Federação                                                                                                                                                                                                                                                 0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?     0
# ...

# %%
agrupado = df.groupby(['Ano de nascimento']).size()
agrupado
# Out:
# Ano de nascimento
# 1921.0     1
# 1924.0     1
# 1925.0     3
# 1927.0     3
# 1928.0     4
#           ..
# 2000.0    50
# 2001.0    40
# 2002.0    36
# 2003.0    32
# 2004.0    23
# Length: 81, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                           0
# Unidade da Federação                                                                                                                                                                                                                                                 0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?     0
# ...

# %%
agrupado = df.groupby(['Sexo']).size()
agrupado
# Out:
# Sexo
# 1.0    1356
# 2.0    3424
# dtype: int64

# %%
agrupado = df.groupby(['Cor ou raça']).size()
agrupado
# Out:
# Cor ou raça
# 1.0    2168
# 2.0     438
# 3.0      28
# 4.0    2113
# 5.0      33
# dtype: int64

# %%
# Pessoas que tiveram diagnóstico de toc: 1.0, Pessoas que não tiveram: 2.0,
agrupado = df.groupby(['Diagnóstico de TOC (Transtorno obsessivo compulsivo) ']).size()
agrupado
# Out:
# Diagnóstico de TOC (Transtorno obsessivo compulsivo)
# 1.0    3661
# 2.0    1119
# dtype: int64

# %%
# Pessoas que tiveram diagnóstico de toc: 1.0, Pessoas que não tiveram: 2.0,
agrupado = df.groupby(['De um modo geral, como é o estado de saúde de________']).size()
agrupado
# Out:
# De um modo geral, como é o estado de saúde de________
# 1.0     505
# 2.0    1932
# 3.0    1721
# 4.0     460
# 5.0     162
# dtype: int64

# %%
df['De um modo geral, como é o estado de saúde de________'].describe()
# Out:
# count    4780.000000
# mean        2.548536
# std         0.924628
# min         1.000000
# 25%         2.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: De um modo geral, como é o estado de saúde de________, dtype: float64

# %%
import pandas as pd

# Mapear os valores 1 para 2 e 5 para 4 na coluna
mapeamento = {2: 1, 5: 4}
df['De um modo geral, como é o estado de saúde de________'] = df['De um modo geral, como é o estado de saúde de________'].replace(mapeamento)

import pandas as pd

# Mapear os valores 1 para 1, 2 para 2,
mapeamento = {4: 2}
df['De um modo geral, como é o estado de saúde de________'] = df['De um modo geral, como é o estado de saúde de________'].replace(mapeamento)

# Verificar os resultados
print(df['De um modo geral, como é o estado de saúde de________'].unique())
# Out:
# [3. 2. 1.]

# %%
# Pessoas que o estado de saude é 1 para bom, 2 para ruim e 3 para regular 
agrupado = df.groupby(['De um modo geral, como é o estado de saúde de________']).size()
agrupado
# Out:
# De um modo geral, como é o estado de saúde de________
# 1.0    2437
# 2.0     622
# 3.0    1721
# dtype: int64

# %%
# Pessoas que o estado de saude é 1 para bom, 2 para ruim e 3 para regular 
agrupado = df.groupby(['De um modo geral, como é o estado de saúde de________']).size()
agrupado
# Out:
# De um modo geral, como é o estado de saúde de________
# 1.0    2437
# 2.0     622
# 3.0    1721
# dtype: int64

# %%
agrupado = df.groupby(['Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc? ']).size()
agrupado
# Out:
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?
# 1.0     281
# 2.0    4499
# dtype: int64

# %%
# Pessoas que o estado de saude é 1 para bom, 2 para ruim e 3 para regular 
agrupado = df.groupby(['Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________? ']).size()
agrupado
# Out:
# Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?
# 1.0     499
# 2.0    2120
# 3.0    1554
# 4.0     458
# 5.0     149
# dtype: int64

# %%
import pandas as pd

# Mapear os valores 1 para 2 e 5 para 4 na coluna
mapeamento = {2: 1, 5: 4}
df['Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________? '] = df['Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________? '].replace(mapeamento)

import pandas as pd

# Mapear os valores 1 para 1, 2 para 2, e 3 para 3
mapeamento = {4: 2}
df['Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________? '] = df['Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________? '].replace(mapeamento)

# Verificar os resultados
print(df['Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________? '].unique())
# Out:
# [1. 2. 3.]

# %%
# Pessoas que o estado de saude é 1 para bom, 2 para ruim e 3 para regular 
agrupado = df.groupby(['Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________? ']).size()
agrupado
# Out:
# Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?
# 1.0    2619
# 2.0     607
# 3.0    1554
# dtype: int64

# %%
agrupado1 = df.groupby(['Por causa da doença mental Faz acompanhamento regular com profissional de saúde']).size()
agrupado1
# Out:
# Por causa da doença mental Faz acompanhamento regular com profissional de saúde
# 1.0    2366
# 2.0    1043
# 3.0     655
# 4.0     474
# 5.0     242
# dtype: int64

# %%
df['Diagnóstico de TOC (Transtorno obsessivo compulsivo) '].describe()
# Out:
# count    4780.00000
# mean        1.23410
# std         0.42348
# min         1.00000
# 25%         1.00000
# 50%         1.00000
# 75%         1.00000
# max         2.00000
# Name: Diagnóstico de TOC (Transtorno obsessivo compulsivo) , dtype: float64

# %%
# Verificando a quantidade de linhas e colunas do arquivo
df.shape
# Out:
# (4780, 16)

# %%
# Salvando arquivo reduzido como csv
df.to_csv('pns-reduzido-2019-notnull.csv', sep=',', encoding='utf-8')

# %%
agrupado = df.groupby(['Por causa da doença mental Faz acompanhamento regular com profissional de saúde']).size()
agrupado
# Out:
# Por causa da doença mental Faz acompanhamento regular com profissional de saúde
# 1.0    2366
# 2.0    1043
# 3.0     655
# 4.0     474
# 5.0     242
# dtype: int64
