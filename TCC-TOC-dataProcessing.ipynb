# %%
import pandas as pd
import seaborn as srn
import statistics as sts
import datetime

# %%
df = pd.read_csv('pns-reduzido-2019.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unidade da Federação  \
# 0           0                    11
# 1           1                    11
# 2           2                    11
# 3           3                    11
# 4           4                    11
#
#    Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?   \
# 0                                                2.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Sexo  Cor ou raça  Qual é o curso que frequenta  \
# 0   2.0          1.0                           NaN
# 1   1.0          4.0                           NaN
# 2   1.0          2.0                           NaN
# 3   1.0          2.0                           4.0
# 4   2.0          4.0                           2.0
#
#    De um modo geral, como é o estado de saúde de________  \
# 0                                                3.0
# 1                                                3.0
# 2                                                3.0
# 3                                                2.0
# 4                                                2.0
#
#     Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?  \
# 0                                                2.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?   \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                2.0
# 4                                                2.0
#
#    Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?   \
# 0                                                2.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Quando ____ consultou um médico pela última vez  \
# 0                                              1.0
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              1.0
#
#    O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Por causa da doença mental Faz acompanhamento regular com profissional de saúde  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Atualmente, o(a) Sr(a) fuma algum produto do tabaco?   \
# 0                                                3.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente?   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Diagnóstico de TOC (Transtorno obsessivo compulsivo)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 21 columns]

# %%
print(df.shape)
# Out:
# (293726, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293726 entries, 0 to 293725
# Data columns (total 21 columns):
#  #   Column                                                                                                                                                                                                                                                             Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                             --------------   -----
#  0   Unnamed: 0                                                                                                                                                                                                                                                         293726 non-null  int64
#  1   Unidade da Federação                                                                                                                                                                                                                                               293726 non-null  int64
#  2   Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?   4905 non-null    float64
#  3   Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?                                                                                                                             90846 non-null   float64
#  4   Sexo                                                                                                                                                                                                                                                               279382 non-null  float64
#  5   Cor ou raça                                                                                                                                                                                                                                                        279382 non-null  float64
#  6   Qual é o curso que frequenta                                                                                                                                                                                                                                       78261 non-null   float64
#  7   De um modo geral, como é o estado de saúde de________                                                                                                                                                                                                              279382 non-null  float64
#  8    Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas                                                                                                                                               21952 non-null   float64
#  9   Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?                                                                                                                                                                                            90846 non-null   float64
#  10  Ano de nascimento                                                                                                                                                                                                                                                  279382 non-null  float64
#  11  Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)                                                                          6632 non-null    float64
#  12  Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?                                                                                                                    279382 non-null  float64
#  13  Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?                                                                                                                   90846 non-null   float64
#  14  Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)                                                                                                                                79823 non-null   float64
#  15  Quando ____ consultou um médico pela última vez                                                                                                                                                                                                                    279382 non-null  float64
#  16  O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?                                                                                                                                            4905 non-null    float64
#  17  Por causa da doença mental Faz acompanhamento regular com profissional de saúde                                                                                                                                                                                    4905 non-null    float64
#  18  Atualmente, o(a) Sr(a) fuma algum produto do tabaco?                                                                                                                                                                                                               90846 non-null   float64
#  19  E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente?                                                                                                                                                                                                1186 non-null    float64
#  20  Diagnóstico de TOC (Transtorno obsessivo compulsivo)                                                                                                                                                                                                               4905 non-null    float64
# dtypes: float64(19), int64(2)
# memory usage: 47.1 MB

# %%
df.describe()
# Out:
#           Unnamed: 0  Unidade da Federação  \
# count  293726.000000         293726.000000
# mean   146862.500000             28.844716
# std     84791.536921             11.762108
# min         0.000000             11.000000
# 25%     73431.250000             21.000000
# 50%    146862.500000             27.000000
# 75%    220293.750000             35.000000
# max    293725.000000             53.000000
#
#        Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?   \
# count                                        4905.000000
# mean                                            1.938634
# std                                             0.240025
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?   \
# count                                       90846.000000
# mean                                            1.985921
# std                                             0.117816
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#                 Sexo    Cor ou raça  Qual é o curso que frequenta  \
# count  279382.000000  279382.000000                  78261.000000
# mean        1.518788       2.735856                      4.740548
# std         0.499648       1.418659                      2.036012
# min         1.000000       1.000000                      1.000000
# 25%         1.000000       1.000000                      4.000000
# 50%         2.000000       4.000000                      4.000000
# 75%         2.000000       4.000000                      6.000000
# max         2.000000       9.000000                     11.000000
#
#        De um modo geral, como é o estado de saúde de________  \
# count                                      279382.000000
# mean                                            2.191734
# std                                             0.776475
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#         Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas   \
# count                                       21952.000000
# mean                                            6.060359
# std                                             4.461902
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             5.000000
# 75%                                             9.000000
# max                                            14.000000
#
#        Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?  \
# count                                       90846.000000
# mean                                            1.657585
# std                                             0.872154
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)  \
# count                                        6632.000000
# mean                                           15.669783
# std                                            13.169331
# min                                             1.000000
# 25%                                             8.000000
# 50%                                            14.000000
# 75%                                            21.000000
# max                                            99.000000
#
#        Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?   \
# count                                      279382.000000
# mean                                            2.064564
# std                                             0.707883
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             5.000000
#
#        Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?   \
# count                                       90846.000000
# mean                                            1.914823
# std                                             0.279147
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)  \
# count                                       79823.000000
# mean                                            1.490285
# std                                             0.499909
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Quando ____ consultou um médico pela última vez  \
# count                                    279382.000000
# mean                                          1.472661
# std                                           0.928274
# min                                           1.000000
# 25%                                           1.000000
# 50%                                           1.000000
# 75%                                           2.000000
# max                                           5.000000
#
#        O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?  \
# count                                        4905.000000
# mean                                            1.782467
# std                                             0.412610
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Por causa da doença mental Faz acompanhamento regular com profissional de saúde  \
# count                                        4905.000000
# mean                                            2.004281
# std                                             1.225320
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Atualmente, o(a) Sr(a) fuma algum produto do tabaco?   \
# count                                       90846.000000
# mean                                            2.762389
# std                                             0.636955
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             3.000000
#
#        E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente?   \
# count                                        1186.000000
# mean                                            1.471332
# std                                             0.499388
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Diagnóstico de TOC (Transtorno obsessivo compulsivo)
# count                                        4905.000000
# mean                                            1.237309
# std                                             0.425477
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             2.000000
#
# [8 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                                0
# Unidade da Federação                                                                                                                                                                                                                                                      0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?     288821
# Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?                                                                                                                               202880
# Sexo                                                                                                                                                                                                                                                                  14344
# Cor ou raça                                                                                                                                                                                                                                                           14344
# Qual é o curso que frequenta                                                                                                                                                                                                                                         215465
# De um modo geral, como é o estado de saúde de________                                                                                                                                                                                                                 14344
#  Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas                                                                                                                                                 271774
# Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?                                                                                                                                                                                              202880
# Ano de nascimento                                                                                                                                                                                                                                                     14344
# Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)                                                                            287094
# Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?                                                                                                                       14344
# Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?                                                                                                                     202880
# Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)                                                                                                                                  213903
# Quando ____ consultou um médico pela última vez                                                                                                                                                                                                                       14344
# O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?                                                                                                                                              288821
# Por causa da doença mental Faz acompanhamento regular com profissional de saúde                                                                                                                                                                                      288821
# Atualmente, o(a) Sr(a) fuma algum produto do tabaco?                                                                                                                                                                                                                 202880
# E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente?                                                                                                                                                                                                  292540
# Diagnóstico de TOC (Transtorno obsessivo compulsivo)                                                                                                                                                                                                                 288821
# dtype: int64

# %% [markdown]
# ## Processar colunas

# %%
df = pd.read_csv('pns-reduzido-2019.csv')

# %%
now = datetime.datetime.now()
# Defina os limites de idade desejados
limite_inferior = 7
limite_superior = 130

# Filtrar linhas com idade dentro do intervalo desejado
df = df[(df['Ano de nascimento'] <= (now.year - limite_inferior)) & (df['Ano de nascimento'] >= (now.year - limite_superior))]

# Agora, df contém apenas as linhas com idade dentro do intervalo especificado (7 a 130 anos)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                                0
# Unidade da Federação                                                                                                                                                                                                                                                      0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?     249552
# Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?                                                                                                                               167235
# Sexo                                                                                                                                                                                                                                                                      0
# Cor ou raça                                                                                                                                                                                                                                                               0
# Qual é o curso que frequenta                                                                                                                                                                                                                                         181767
# De um modo geral, como é o estado de saúde de________                                                                                                                                                                                                                     0
#  Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas                                                                                                                                                 233806
# Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?                                                                                                                                                                                              167235
# Ano de nascimento                                                                                                                                                                                                                                                         0
# Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)                                                                            254332
# Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?                                                                                                                           0
# Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?                                                                                                                     167235
# Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)                                                                                                                                  177938
# Quando ____ consultou um médico pela última vez                                                                                                                                                                                                                           0
# O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?                                                                                                                                              249552
# Por causa da doença mental Faz acompanhamento regular com profissional de saúde                                                                                                                                                                                      249552
# Atualmente, o(a) Sr(a) fuma algum produto do tabaco?                                                                                                                                                                                                                 167235
# E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente?                                                                                                                                                                                                  253204
# Diagnóstico de TOC (Transtorno obsessivo compulsivo)                                                                                                                                                                                                                 249552
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  Unidade da Federação  \
# 0           0                    11
# 1           1                    11
# 2           2                    11
# 6           6                    11
# 7           7                    11
#
#    Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?   \
# 0                                                2.0
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Sexo  Cor ou raça  Qual é o curso que frequenta  \
# 0   2.0          1.0                           NaN
# 1   1.0          4.0                           NaN
# 2   1.0          2.0                           NaN
# 6   2.0          1.0                           NaN
# 7   1.0          1.0                           6.0
#
#    De um modo geral, como é o estado de saúde de________  \
# 0                                                3.0
# 1                                                3.0
# 2                                                3.0
# 6                                                2.0
# 7                                                2.0
#
#     Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?  \
# 0                                                2.0
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 6  ...
# 7  ...
#
#    Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?   \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 6                                                2.0
# 7                                                2.0
#
#    Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?   \
# 0                                                2.0
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Quando ____ consultou um médico pela última vez  \
# 0                                              1.0
# 1                                              1.0
# 2                                              1.0
# 6                                              2.0
# 7                                              2.0
#
#    O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Por causa da doença mental Faz acompanhamento regular com profissional de saúde  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Atualmente, o(a) Sr(a) fuma algum produto do tabaco?   \
# 0                                                3.0
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente?   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#    Diagnóstico de TOC (Transtorno obsessivo compulsivo)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 6                                                NaN
# 7                                                NaN
#
# [5 rows x 21 columns]

# %%
# Antes de aplicar o dropna
print(df.shape)

# Aplicar o dropna
df.dropna(subset=['Diagnóstico de TOC (Transtorno obsessivo compulsivo) '], inplace=True)

# Depois de aplicar o dropna
print(df.shape)

# Verificar a presença de valores nulos na coluna
print(df['Diagnóstico de TOC (Transtorno obsessivo compulsivo) '].isnull().sum())
# Out:
# (254332, 21)
# (4780, 21)
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                              0
# Unidade da Federação                                                                                                                                                                                                                                                    0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?        0
# Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?                                                                                                                                  0
# Sexo                                                                                                                                                                                                                                                                    0
# Cor ou raça                                                                                                                                                                                                                                                             0
# Qual é o curso que frequenta                                                                                                                                                                                                                                         4212
# De um modo geral, como é o estado de saúde de________                                                                                                                                                                                                                   0
#  Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas                                                                                                                                                 3714
# Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?                                                                                                                                                                                                 0
# Ano de nascimento                                                                                                                                                                                                                                                       0
# Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)                                                                            4780
# Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?                                                                                                                         0
# Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?                                                                                                                        0
# Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)                                                                                                                                   704
# Quando ____ consultou um médico pela última vez                                                                                                                                                                                                                         0
# O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?                                                                                                                                                 0
# Por causa da doença mental Faz acompanhamento regular com profissional de saúde                                                                                                                                                                                         0
# Atualmente, o(a) Sr(a) fuma algum produto do tabaco?                                                                                                                                                                                                                    0
# E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente?                                                                                                                                                                                                  4696
# Diagnóstico de TOC (Transtorno obsessivo compulsivo)                                                                                                                                                                                                                    0
# dtype: int64

# %%
df = df.drop(columns=['Faixa de rendimento domiciliar per capita (exclusive o rendimento das pessoas cuja condição na unidade domiciliar era pensionista, empregado doméstico ou parente do empregado doméstico)'])
df = df.drop(columns=['Qual é o curso que frequenta'])
df = df.drop(columns=['E no passado, o(a) Sr(a) fumou algum produto do tabaco diariamente? '])
df = df.drop(columns=['Alguma dessas doenças limita de alguma forma suas atividades habituais (trabalhar, ir à escola, brincar, afazeres domésticos, etc.)'])
df = df.drop(columns=[' Qual foi o principal motivo de saúde que impediu ___ de realizar suas atividades habituais nas duas últimas semanas '])

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                           0
# Unidade da Federação                                                                                                                                                                                                                                                 0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?     0
# Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?                                                                                                                               0
# Sexo                                                                                                                                                                                                                                                                 0
# Cor ou raça                                                                                                                                                                                                                                                          0
# De um modo geral, como é o estado de saúde de________                                                                                                                                                                                                                0
# Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?                                                                                                                                                                                              0
# Ano de nascimento                                                                                                                                                                                                                                                    0
# Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?                                                                                                                      0
# Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?                                                                                                                     0
# Quando ____ consultou um médico pela última vez                                                                                                                                                                                                                      0
# O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?                                                                                                                                              0
# Por causa da doença mental Faz acompanhamento regular com profissional de saúde                                                                                                                                                                                      0
# Atualmente, o(a) Sr(a) fuma algum produto do tabaco?                                                                                                                                                                                                                 0
# Diagnóstico de TOC (Transtorno obsessivo compulsivo)                                                                                                                                                                                                                 0
# dtype: int64

# %%
# Salvando arquivo reduzido como csv
df.to_csv('pns-reduzido-2019-notnull.csv', sep=',', encoding='utf-8')

# %%
agrupado = df.groupby(['Diagnóstico de TOC (Transtorno obsessivo compulsivo) ']).size()
agrupado
# Out:
# Diagnóstico de TOC (Transtorno obsessivo compulsivo)
# 1.0    3661
# 2.0    1119
# dtype: int64

# %%
agrupado = df.groupby(['Ano de nascimento']).size()
agrupado
# Out:
# Ano de nascimento
# 1921.0     1
# 1924.0     1
# 1925.0     3
# 1927.0     3
# 1928.0     4
#           ..
# 2000.0    50
# 2001.0    40
# 2002.0    36
# 2003.0    32
# 2004.0    23
# Length: 81, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                                                                                                                                                                                                                           0
# Unidade da Federação                                                                                                                                                                                                                                                 0
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?     0
# Em geral, em que grau essa doença mental limita as suas atividades habituais (tais como trabalhar, realizar afazeres domésticos etc.)?                                                                                                                               0
# Sexo                                                                                                                                                                                                                                                                 0
# Cor ou raça                                                                                                                                                                                                                                                          0
# De um modo geral, como é o estado de saúde de________                                                                                                                                                                                                                0
# Com que frequência o(a) Sr(a) costuma consumir alguma bebida alcoólica?                                                                                                                                                                                              0
# Ano de nascimento                                                                                                                                                                                                                                                    0
# Considerando saúde como um estado de bem-estar físico e mental, e não somente a ausência de doenças, como é o estado de saúde de _____________?                                                                                                                      0
# Algum médico já lhe deu algum diagnóstico de outra doença crônica (física ou mental) ou doença de longa duração (de mais de 6 meses de duração)?                                                                                                                     0
# Quando ____ consultou um médico pela última vez                                                                                                                                                                                                                      0
# O(A) Sr(a) visita o médico/serviço de saúde regularmente por causa dessa doença mental ou só quando tem algum problema?                                                                                                                                              0
# Por causa da doença mental Faz acompanhamento regular com profissional de saúde                                                                                                                                                                                      0
# Atualmente, o(a) Sr(a) fuma algum produto do tabaco?                                                                                                                                                                                                                 0
# Diagnóstico de TOC (Transtorno obsessivo compulsivo)                                                                                                                                                                                                                 0
# dtype: int64

# %%
agrupado = df.groupby(['Sexo']).size()
agrupado
# Out:
# Sexo
# 1.0    1356
# 2.0    3424
# dtype: int64

# %%
agrupado = df.groupby(['Cor ou raça']).size()
agrupado
# Out:
# Cor ou raça
# 1.0    2168
# 2.0     438
# 3.0      28
# 4.0    2113
# 5.0      33
# dtype: int64

# %%
# Pessoas que tiveram diagnóstico de toc: 1.0, Pessoas que não tiveram: 2.0,
agrupado = df.groupby(['Diagnóstico de TOC (Transtorno obsessivo compulsivo) ']).size()
agrupado
# Out:
# Diagnóstico de TOC (Transtorno obsessivo compulsivo)
# 1.0    3661
# 2.0    1119
# dtype: int64

# %%
# Pessoas que tiveram diagnóstico de doença: 1.0, Pessoas que não tiveram: 2.0
agrupado = df.groupby(['Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc? ']).size()
agrupado
# Out:
# Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?
# 1.0     281
# 2.0    4499
# dtype: int64

# %%
# Verificando a quantidade de linhas e colunas do arquivo
df.shape
# Out:
# (4780, 16)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
x = df[['Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc? ', 'Sexo', 'Cor ou raça']]
y = df['Diagnóstico de TOC (Transtorno obsessivo compulsivo) ' ]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %%
y_train.head()
# Out:
# 116329    2.0
# 66936     1.0
# 162363    1.0
# 30947     1.0
# 235059    1.0
# Name: Diagnóstico de TOC (Transtorno obsessivo compulsivo) , dtype: float64

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1434 entries, 123368 to 173686
# Data columns (total 3 columns):
#  #   Column                                                                                                                                                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                             --------------  -----
#  0   Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc?   1434 non-null   float64
#  1   Sexo                                                                                                                                                                                                                                                               1434 non-null   float64
#  2   Cor ou raça                                                                                                                                                                                                                                                        1434 non-null   float64
# dtypes: float64(3)
# memory usage: 44.8 KB

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(x_train, y_train)
forest_pred = clf.predict(x_test)

# %%
print(confusion_matrix(y_test, forest_pred))
print(classification_report(y_test, forest_pred))
# Out:
# [[1101   16]
#  [ 259   58]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Gabriel Vidigal\Documents\tcc-toc-arquivos\tcc-toc\TCC-TOC-dataProcessing.ipynb Cell 33 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Gabriel%20Vidigal/Documents/tcc-toc-arquivos/tcc-toc/TCC-TOC-dataProcessing.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> print(confusion_matrix(y_test, forest_pred))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Gabriel%20Vidigal/Documents/tcc-toc-arquivos/tcc-toc/TCC-TOC-dataProcessing.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> print(classification_report(y_test, forest_pred))
#
# NameError: name 'classification_report' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report

def knnRange(min, max):
    for i in range(min, max):
    
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(x_train, y_train)
        pred_i = knn.predict(x_test)
        error_rate.append(np.mean(pred_i != y_test))
        
        # Imprima a matriz de confusão e o relatório de classificação para cada valor de k
        print(f"K = {i}")
        print("Matriz de Confusão:\n", confusion_matrix(y_test, pred_i))
        print("Relatório de Classificação:\n", classification_report(y_test, pred_i))
        
    plt.figure(figsize=(25,4))
    plt.plot(range(1,100),error_rate,color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
    plt.title('Error Rate vs. K Value')
    plt.xlabel('K')
    plt.ylabel('Error Rate')    

knnRange(1, 100)
# Out:
# K = 1
# Matriz de Confusão:
#  [[1090   41]
#  [ 302   39]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.78      0.96      0.86      1131
#          2.0       0.49      0.11      0.19       341
#
#     accuracy                           0.77      1472
#    macro avg       0.64      0.54      0.52      1472
# weighted avg       0.71      0.77      0.71      1472
#
# K = 2
# Matriz de Confusão:
#  [[1120   11]
#  [ 305   36]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.79      0.99      0.88      1131
#          2.0       0.77      0.11      0.19       341
#
#     accuracy                           0.79      1472
#    macro avg       0.78      0.55      0.53      1472
# weighted avg       0.78      0.79      0.72      1472
#
# K = 3
# Matriz de Confusão:
#  [[1109   22]
#  [ 285   56]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.72      0.16      0.27       341
#
#     accuracy                           0.79      1472
#    macro avg       0.76      0.57      0.57      1472
# weighted avg       0.78      0.79      0.74      1472
#
# K = 4
# Matriz de Confusão:
#  [[1116   15]
#  [ 289   52]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.79      0.99      0.88      1131
#          2.0       0.78      0.15      0.25       341
#
#     accuracy                           0.79      1472
#    macro avg       0.79      0.57      0.57      1472
# weighted avg       0.79      0.79      0.74      1472
#
# K = 5
# Matriz de Confusão:
#  [[1115   16]
#  [ 289   52]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.79      0.99      0.88      1131
#          2.0       0.76      0.15      0.25       341
#
#     accuracy                           0.79      1472
#    macro avg       0.78      0.57      0.57      1472
# weighted avg       0.79      0.79      0.73      1472
#
# K = 6
# Matriz de Confusão:
#  [[1114   17]
#  [ 289   52]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.79      0.98      0.88      1131
#          2.0       0.75      0.15      0.25       341
#
#     accuracy                           0.79      1472
#    macro avg       0.77      0.57      0.57      1472
# weighted avg       0.78      0.79      0.73      1472
#
# K = 7
# Matriz de Confusão:
#  [[1111   20]
#  [ 275   66]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.77      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.78      0.59      0.60      1472
# weighted avg       0.79      0.80      0.75      1472
#
# K = 8
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 9
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 10
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 11
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 12
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 13
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 14
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 15
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 16
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 17
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 18
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 19
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 20
# Matriz de Confusão:
#  [[1115   16]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.99      0.88      1131
#          2.0       0.80      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 21
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 22
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 23
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 24
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 25
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 26
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 27
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 28
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 29
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 30
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 31
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 32
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 33
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 34
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 35
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 36
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 37
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 38
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 39
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 40
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 41
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 42
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 43
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 44
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 45
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 46
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 47
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 48
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 49
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 50
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 51
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 52
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 53
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 54
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 55
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 56
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 57
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 58
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 59
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 60
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 61
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 62
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 63
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 64
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 65
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 66
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 67
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 68
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 69
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 70
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 71
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 72
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 73
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 74
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 75
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 76
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 77
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 78
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 79
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 80
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 81
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 82
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 83
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 84
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 85
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 86
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 87
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 88
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 89
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 90
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 91
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 92
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 93
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 94
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 95
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 96
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 97
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 98
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472
#
# K = 99
# Matriz de Confusão:
#  [[1114   17]
#  [ 276   65]]
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          1.0       0.80      0.98      0.88      1131
#          2.0       0.79      0.19      0.31       341
#
#     accuracy                           0.80      1472
#    macro avg       0.80      0.59      0.60      1472
# weighted avg       0.80      0.80      0.75      1472

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
y_test.head()
# Out:
# 175160    1.0
# 217697    2.0
# 123834    1.0
# 242317    1.0
# 51661     1.0
# Name: Diagnóstico de TOC (Transtorno obsessivo compulsivo) , dtype: float64

# %% [markdown]
# ## XGBOOST CLASSIFICADOR ???

# %%
# !pip install tensorflow
# !pip install xgboost

import tensorflow as tf
#tf.Session(config=tf.ConfigProto(log_device_placement=True))
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder

# %%
# GridSearch como classificador

model = XGBClassifier(
 learning_rate =1,
 min_child_weight=1,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
n_estimators = [100, 1000]
max_depth = [1, 100]
param_grid = dict(max_depth=max_depth, n_estimators=n_estimators)
kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=7)
grid_search = GridSearchCV(model, param_grid, scoring="roc_auc", n_jobs=-1, cv=kfold, verbose=1)

# %%
# Adaptação do dataset para ter valores 0 = red e 1 = white

df['Diagnóstico de TOC (Transtorno obsessivo compulsivo) ' ].replace(('red', 'white'), (1, 0), inplace=True)

seed = 42 # Para que a separação dos dados ocorra sempre a partir da mesma semente (seed), e seja reproduzível em qualquer execução
array = df.values

X = df[['Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc? ', 'Sexo', 'Cor ou raça']]
Y = df['Diagnóstico de TOC (Transtorno obsessivo compulsivo) ' ]

test_size = 0.3 # Tamanho do conjunto de teste
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(y)
# Ajuste do modelo

grid_result = grid_search.fit(X, Y)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits

# %%
# Resultados

import matplotlib.pyplot as plt
#matplotlib.use('Agg')

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

# Plota os resultados

scores = np.array(means).reshape(len(max_depth), len(n_estimators))
for i, value in enumerate(max_depth):
    plt.plot(n_estimators, scores[i], label='depth: ' + str(value))
plt.legend()
plt.xlabel('n_estimators')
plt.ylabel('Log Loss')
#plt.savefig('n_estimators_vs_max_depth.png')
plt.show()
# Out:
# Best: 1.000000 using {'max_depth': 1, 'n_estimators': 100}
# 1.000000 (0.000000) with: {'max_depth': 1, 'n_estimators': 100}
# 1.000000 (0.000000) with: {'max_depth': 1, 'n_estimators': 1000}
# 1.000000 (0.000000) with: {'max_depth': 100, 'n_estimators': 100}
# 1.000000 (0.000000) with: {'max_depth': 100, 'n_estimators': 1000}

# %% [markdown]
# ## xgboost regressor ???

# %%
model = XGBRegressor(n_estimators=100,
                    learning_rate=0.1,
                    max_depth=6,
                    random_state=42,
                    n_jobs=-1,
                    early_stopping_rounds=10)

# %%
# Ajusto do modelo

model.fit(
    x_train, 
    y_train, 
    eval_metric="mae",
    eval_set=[(x_test, y_test)],
    verbose=True)
# Out:
# [0]	validation_0-mae:0.35589
# [1]	validation_0-mae:0.35191
# [2]	validation_0-mae:0.34833
# [3]	validation_0-mae:0.34510
# [4]	validation_0-mae:0.34220
# [5]	validation_0-mae:0.33959
# [6]	validation_0-mae:0.33724
# [7]	validation_0-mae:0.33512
# [8]	validation_0-mae:0.33322
# [9]	validation_0-mae:0.33150
# [10]	validation_0-mae:0.32996
# [11]	validation_0-mae:0.32856
# [12]	validation_0-mae:0.32731
# [13]	validation_0-mae:0.32618
# [14]	validation_0-mae:0.32517
# [15]	validation_0-mae:0.32425
# [16]	validation_0-mae:0.32343
# [17]	validation_0-mae:0.32269
# [18]	validation_0-mae:0.32202
# [19]	validation_0-mae:0.32142
# [20]	validation_0-mae:0.32088
# [21]	validation_0-mae:0.32038
# [22]	validation_0-mae:0.31994
# [23]	validation_0-mae:0.31954
# [24]	validation_0-mae:0.31918
# [25]	validation_0-mae:0.31886
# [26]	validation_0-mae:0.31857
# [27]	validation_0-mae:0.31830
# [28]	validation_0-mae:0.31807
# [29]	validation_0-mae:0.31785
# [30]	validation_0-mae:0.31766
# [31]	validation_0-mae:0.31749
# [32]	validation_0-mae:0.31733
# [33]	validation_0-mae:0.31719
# [34]	validation_0-mae:0.31706
# [35]	validation_0-mae:0.31695
# [36]	validation_0-mae:0.31685
# [37]	validation_0-mae:0.31675
# [38]	validation_0-mae:0.31667
# [39]	validation_0-mae:0.31660
# [40]	validation_0-mae:0.31653
# [41]	validation_0-mae:0.31647
# [42]	validation_0-mae:0.31641
# [43]	validation_0-mae:0.31636
# [44]	validation_0-mae:0.31632
# [45]	validation_0-mae:0.31628
# [46]	validation_0-mae:0.31624
# [47]	validation_0-mae:0.31621
# [48]	validation_0-mae:0.31618
# [49]	validation_0-mae:0.31615
# [50]	validation_0-mae:0.31613
# [51]	validation_0-mae:0.31611
# [52]	validation_0-mae:0.31609
# [53]	validation_0-mae:0.31607
# [54]	validation_0-mae:0.31606
# [55]	validation_0-mae:0.31604
# [56]	validation_0-mae:0.31603
# [57]	validation_0-mae:0.31602
# [58]	validation_0-mae:0.31601
# [59]	validation_0-mae:0.31600
# [60]	validation_0-mae:0.31599
# [61]	validation_0-mae:0.31599
# [62]	validation_0-mae:0.31598
# [63]	validation_0-mae:0.31597
# [64]	validation_0-mae:0.31597
# [65]	validation_0-mae:0.31596
# [66]	validation_0-mae:0.31596
# [67]	validation_0-mae:0.31595
# [68]	validation_0-mae:0.31595
# [69]	validation_0-mae:0.31595
# [70]	validation_0-mae:0.31594
# [71]	validation_0-mae:0.31594
# [72]	validation_0-mae:0.31594
# [73]	validation_0-mae:0.31594
# [74]	validation_0-mae:0.31594
# [75]	validation_0-mae:0.31593
# [76]	validation_0-mae:0.31593
# [77]	validation_0-mae:0.31593
# [78]	validation_0-mae:0.31593
# [79]	validation_0-mae:0.31593
# [80]	validation_0-mae:0.31593
# [81]	validation_0-mae:0.31593
# [82]	validation_0-mae:0.31592
# [83]	validation_0-mae:0.31592
# [84]	validation_0-mae:0.31592
# [85]	validation_0-mae:0.31592
# [86]	validation_0-mae:0.31592
# [87]	validation_0-mae:0.31592
# [88]	validation_0-mae:0.31592
# [89]	validation_0-mae:0.31592
# [90]	validation_0-mae:0.31592
# [91]	validation_0-mae:0.31592
# [92]	validation_0-mae:0.31592
# [93]	validation_0-mae:0.31592
# [94]	validation_0-mae:0.31592
# [95]	validation_0-mae:0.31592
# [96]	validation_0-mae:0.31592
# [97]	validation_0-mae:0.31592
# [98]	validation_0-mae:0.31592
# [99]	validation_0-mae:0.31592
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=10,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=-1,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Realizada a predição nos dados de teste

y_pred = model.predict(x_test)
predictions = [round(value) for value in y_pred]

# %%
# Avalia a predição

accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 80.03%

# %% [markdown]
# ## estudando rede neural ???

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Sexo'] = label_encoder.fit_transform(df['Sexo'])
df['Cor ou raça'] = label_encoder.fit_transform(df['Cor ou raça'])

# Defina seus recursos (X) e rótulo alvo (y)
x = df[['Algum médico ou profissional de saúde (como psiquiatra ou psicólogo) já lhe deu o diagnóstico de outra doença mental, como transtorno de ansiedade, síndrome do pânico, esquizofrenia, transtorno bipolar, psicose ou TOC (Transtorno Obsessivo Compulsivo) etc? ', 'Sexo', 'Cor ou raça']]
y = df['Diagnóstico de TOC (Transtorno obsessivo compulsivo) ' ]

# Divida os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Crie o modelo da rede neural
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=3))  # 3 neurônios na camada de entrada
model.add(Dense(32, activation='relu'))  # Camada oculta com 32 neurônios
model.add(Dense(1, activation='sigmoid'))  # Camada de saída com 1 neurônio (para classificação binária)

# Compile o modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Treine o modelo
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 108/108 [==============================] - 2s 7ms/step - loss: -0.8140 - accuracy: 0.7163 - val_loss: -2.6152 - val_accuracy: 0.7649
# Epoch 2/100
# 108/108 [==============================] - 0s 4ms/step - loss: -9.1059 - accuracy: 0.7617 - val_loss: -20.8307 - val_accuracy: 0.7649
# Epoch 3/100
# 108/108 [==============================] - 0s 4ms/step - loss: -47.7653 - accuracy: 0.7617 - val_loss: -85.1268 - val_accuracy: 0.7649
# Epoch 4/100
# 108/108 [==============================] - 0s 4ms/step - loss: -146.2437 - accuracy: 0.7617 - val_loss: -221.1356 - val_accuracy: 0.7649
# Epoch 5/100
# 108/108 [==============================] - 1s 5ms/step - loss: -324.6195 - accuracy: 0.7617 - val_loss: -445.6232 - val_accuracy: 0.7649
# Epoch 6/100
# 108/108 [==============================] - 1s 5ms/step - loss: -603.9228 - accuracy: 0.7617 - val_loss: -782.1476 - val_accuracy: 0.7649
# Epoch 7/100
# 108/108 [==============================] - 1s 5ms/step - loss: -1005.5614 - accuracy: 0.7617 - val_loss: -1245.6735 - val_accuracy: 0.7649
# Epoch 64/100
# 108/108 [==============================] - 1s 9ms/step - loss: -429738.8125 - accuracy: 0.7617 - val_loss: -434874.3125 - val_accuracy: 0.7649
# Epoch 65/100
# 108/108 [==============================] - 1s 12ms/step - loss: -446526.3750 - accuracy: 0.7617 - val_loss: -451588.4688 - val_accuracy: 0.7649
# Epoch 66/100
# 108/108 [==============================] - 1s 6ms/step - loss: -463616.1875 - accuracy: 0.7617 - val_loss: -468797.1250 - val_accuracy: 0.7649
# Epoch 67/100
# 108/108 [==============================] - 1s 5ms/step - loss: -481087.5938 - accuracy: 0.7617 - val_loss: -486294.3438 - val_accuracy: 0.7649
# Epoch 68/100
# 108/108 [==============================] - 1s 6ms/step - loss: -498991.5312 - accuracy: 0.7617 - val_loss: -504193.1250 - val_accuracy: 0.7649
# Epoch 69/100
# 108/108 [==============================] - 1s 6ms/step - loss: -517228.1250 - accuracy: 0.7617 - val_loss: -522591.0938 - val_accuracy: 0.7649
# Epoch 70/100
# 108/108 [==============================] - 1s 9ms/step - loss: -535936.6250 - accuracy: 0.7617 - val_loss: -541224.2500 - val_accuracy: 0.7649
# Epoch 71/100
# 108/108 [==============================] - 1s 8ms/step - loss: -554978.0625 - accuracy: 0.7617 - val_loss: -560326.3750 - val_accuracy: 0.7649
# Epoch 72/100
# 108/108 [==============================] - 1s 6ms/step - loss: -574425.5625 - accuracy: 0.7617 - val_loss: -579915.8750 - val_accuracy: 0.7649
# Epoch 73/100
# 108/108 [==============================] - 1s 6ms/step - loss: -594306.1875 - accuracy: 0.7617 - val_loss: -599887.5625 - val_accuracy: 0.7649
# Epoch 74/100
# 108/108 [==============================] - 1s 7ms/step - loss: -614630.0000 - accuracy: 0.7617 - val_loss: -620285.6875 - val_accuracy: 0.7649
# Epoch 75/100
# 108/108 [==============================] - 1s 12ms/step - loss: -635281.8125 - accuracy: 0.7617 - val_loss: -640728.0625 - val_accuracy: 0.7649
# Epoch 76/100
# 108/108 [==============================] - 1s 11ms/step - loss: -656341.2500 - accuracy: 0.7617 - val_loss: -662033.0000 - val_accuracy: 0.7649
# Epoch 77/100
# 108/108 [==============================] - 1s 9ms/step - loss: -677963.6875 - accuracy: 0.7617 - val_loss: -683603.1875 - val_accuracy: 0.7649
# Epoch 78/100
# 108/108 [==============================] - 1s 11ms/step - loss: -699808.6250 - accuracy: 0.7617 - val_loss: -705341.3750 - val_accuracy: 0.7649
# Epoch 79/100
# 108/108 [==============================] - 1s 6ms/step - loss: -722273.4375 - accuracy: 0.7617 - val_loss: -727974.1875 - val_accuracy: 0.7649
# Epoch 80/100
# 108/108 [==============================] - 1s 10ms/step - loss: -744886.6875 - accuracy: 0.7617 - val_loss: -750653.0625 - val_accuracy: 0.7649
# Epoch 81/100
# 108/108 [==============================] - 1s 10ms/step - loss: -768013.6250 - accuracy: 0.7617 - val_loss: -773593.7500 - val_accuracy: 0.7649
# Epoch 82/100
